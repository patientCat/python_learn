# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# %%
# 构建模型

class SimpleModel(torch.nn.Module):
    def __init__(self):
        super(SimpleModel, self).__init__()
        self.linear1 = torch.nn.Linear(8, 6)
        self.linear2 = torch.nn.Linear(6, 4)
        self.linear3 = torch.nn.Linear(4, 1)
        self.sigmoid = torch.nn.Sigmoid()

    def forward(self, x):
        x = self.sigmoid(self.linear1(x))
        x = self.sigmoid(self.linear2(x))
        x = self.sigmoid(self.linear3(x))
        return x

# %%
filename = "../data/diabetes.csv"
loadtxt = np.loadtxt(filename, delimiter=",", dtype=np.float32)

oneline = loadtxt[0, :]
n_item = loadtxt.shape[0]
print(oneline.shape)
# Out:
# (9,)

# %%
data = loadtxt[:, 0:-1]
print(data.shape)
data = torch.tensor(data, requires_grad=True)
labels = loadtxt[:, -1]
labels = torch.tensor(labels, requires_grad=True).view(n_item, 1)
# Out:
# (768, 8)

# %%
model = SimpleModel()
bce_loss = torch.nn.BCELoss(size_average=True)
sgd = torch.optim.SGD(model.parameters(), lr=0.01)
epoch = 1000
loss_history = []
for i in range(epoch):
    prediction = model.forward(data)
    loss = bce_loss(prediction, labels)
    loss_history.append(loss.item())
    sgd.zero_grad()
    loss.backward()
    sgd.step()
# Out:
# /Users/luke/miniconda3/envs/demo/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='mean' instead.
#   warnings.warn(warning.format(ret))
# Parameter containing:
# tensor([[ 0.1500, -0.0632,  0.1014,  0.0290, -0.3170,  0.1091, -0.0027, -0.2973],
#         [ 0.0723, -0.2046,  0.1399, -0.0124, -0.2022, -0.0602,  0.3326, -0.3304],
#         [-0.1459,  0.3022, -0.1596, -0.1916,  0.0815, -0.0546,  0.1753,  0.2236],
#         [-0.2135, -0.3491,  0.0299, -0.0285, -0.2962,  0.3508,  0.2133, -0.1651],
#         [-0.1729, -0.1111,  0.1898,  0.3510, -0.3208,  0.3152, -0.3225, -0.2181],
#         [-0.3200, -0.2328, -0.2876, -0.1766,  0.1910,  0.1553,  0.1089, -0.0048]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2849,  0.3379,  0.3220, -0.3423, -0.2008,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3823, -0.2464, -0.2041, -0.0024, -0.0146,  0.4058],
#         [-0.2487,  0.2933,  0.3558, -0.2035, -0.2280,  0.2970],
#         [ 0.3403, -0.1067, -0.3528,  0.3600,  0.0938,  0.2990],
#         [ 0.0105, -0.1019, -0.0889,  0.2491, -0.1986,  0.3993]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2020,  0.2702, -0.3831,  0.3519], requires_grad=True)
# Parameter containing:
# tensor([[-0.0985, -0.0557,  0.2616,  0.4429]], requires_grad=True)
# Parameter containing:
# tensor([0.4740], requires_grad=True)
# loss=0.8656423091888428
# Parameter containing:
# tensor([[ 0.1500, -0.0634,  0.1013,  0.0289, -0.3170,  0.1090, -0.0027, -0.2974],
#         [ 0.0723, -0.2046,  0.1399, -0.0124, -0.2022, -0.0602,  0.3326, -0.3304],
#         [-0.1459,  0.3022, -0.1596, -0.1916,  0.0815, -0.0546,  0.1753,  0.2236],
#         [-0.2135, -0.3491,  0.0299, -0.0285, -0.2962,  0.3508,  0.2133, -0.1651],
#         [-0.1729, -0.1110,  0.1899,  0.3510, -0.3208,  0.3152, -0.3225, -0.2181],
#         [-0.3200, -0.2328, -0.2876, -0.1766,  0.1910,  0.1553,  0.1089, -0.0048]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2849,  0.3379,  0.3220, -0.3423, -0.2008,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3823, -0.2464, -0.2041, -0.0024, -0.0146,  0.4058],
#         [-0.2487,  0.2933,  0.3559, -0.2035, -0.2280,  0.2970],
#         [ 0.3403, -0.1067, -0.3529,  0.3600,  0.0937,  0.2990],
#         [ 0.0105, -0.1019, -0.0893,  0.2491, -0.1987,  0.3992]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2021,  0.2702, -0.3833,  0.3516], requires_grad=True)
# Parameter containing:
# tensor([[-0.1001, -0.0578,  0.2605,  0.4411]], requires_grad=True)
# Parameter containing:
# tensor([0.4707], requires_grad=True)
# loss=0.8634384274482727
# Parameter containing:
# tensor([[ 0.1500, -0.0635,  0.1011,  0.0289, -0.3170,  0.1090, -0.0027, -0.2974],
#         [ 0.0723, -0.2046,  0.1399, -0.0124, -0.2022, -0.0602,  0.3326, -0.3304],
#         [-0.1459,  0.3022, -0.1596, -0.1916,  0.0815, -0.0546,  0.1753,  0.2236],
#         [-0.2135, -0.3491,  0.0299, -0.0285, -0.2962,  0.3508,  0.2133, -0.1651],
#         [-0.1729, -0.1109,  0.1899,  0.3510, -0.3208,  0.3152, -0.3225, -0.2181],
#         [-0.3200, -0.2328, -0.2877, -0.1766,  0.1909,  0.1553,  0.1089, -0.0048]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2849,  0.3379,  0.3220, -0.3423, -0.2008,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3823, -0.2464, -0.2040, -0.0024, -0.0146,  0.4058],
#         [-0.2487,  0.2933,  0.3559, -0.2035, -0.2279,  0.2970],
#         [ 0.3403, -0.1067, -0.3531,  0.3600,  0.0936,  0.2990],
#         [ 0.0105, -0.1019, -0.0896,  0.2491, -0.1989,  0.3992]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2022,  0.2702, -0.3835,  0.3512], requires_grad=True)
# Parameter containing:
# tensor([[-0.1017, -0.0598,  0.2594,  0.4393]], requires_grad=True)
# Parameter containing:
# tensor([0.4675], requires_grad=True)
# loss=0.8612554669380188
# Parameter containing:
# tensor([[ 0.1500, -0.0637,  0.1010,  0.0289, -0.3170,  0.1089, -0.0027, -0.2975],
#         [ 0.0724, -0.2046,  0.1399, -0.0124, -0.2022, -0.0602,  0.3326, -0.3304],
#         [-0.1459,  0.3022, -0.1596, -0.1916,  0.0815, -0.0546,  0.1753,  0.2236],
#         [-0.2135, -0.3491,  0.0299, -0.0285, -0.2962,  0.3508,  0.2133, -0.1651],
#         [-0.1729, -0.1108,  0.1900,  0.3510, -0.3208,  0.3152, -0.3225, -0.2180],
#         [-0.3200, -0.2329, -0.2877, -0.1766,  0.1908,  0.1553,  0.1089, -0.0049]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2849,  0.3379,  0.3220, -0.3423, -0.2008,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3823, -0.2464, -0.2039, -0.0024, -0.0145,  0.4058],
#         [-0.2487,  0.2933,  0.3560, -0.2035, -0.2279,  0.2970],
#         [ 0.3403, -0.1067, -0.3533,  0.3600,  0.0935,  0.2990],
#         [ 0.0105, -0.1019, -0.0900,  0.2491, -0.1990,  0.3992]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2023,  0.2703, -0.3837,  0.3509], requires_grad=True)
# Parameter containing:
# tensor([[-0.1033, -0.0618,  0.2583,  0.4376]], requires_grad=True)
# Parameter containing:
# tensor([0.4643], requires_grad=True)
# loss=0.8590934872627258
# Parameter containing:
# tensor([[ 0.1500, -0.0639,  0.1008,  0.0288, -0.3170,  0.1089, -0.0027, -0.2975],
#         [ 0.0724, -0.2046,  0.1399, -0.0124, -0.2022, -0.0602,  0.3326, -0.3304],
#         [-0.1459,  0.3022, -0.1596, -0.1916,  0.0815, -0.0546,  0.1753,  0.2236],
#         [-0.2135, -0.3491,  0.0299, -0.0285, -0.2962,  0.3508,  0.2133, -0.1651],
#         [-0.1729, -0.1107,  0.1900,  0.3510, -0.3207,  0.3153, -0.3225, -0.2180],
#         [-0.3200, -0.2329, -0.2877, -0.1766,  0.1907,  0.1552,  0.1089, -0.0049]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2849,  0.3379,  0.3220, -0.3423, -0.2008,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3823, -0.2464, -0.2038, -0.0024, -0.0145,  0.4058],
#         [-0.2487,  0.2933,  0.3560, -0.2035, -0.2279,  0.2970],
#         [ 0.3403, -0.1067, -0.3535,  0.3600,  0.0934,  0.2990],
#         [ 0.0105, -0.1019, -0.0903,  0.2491, -0.1992,  0.3992]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2024,  0.2703, -0.3839,  0.3505], requires_grad=True)
# Parameter containing:
# tensor([[-0.1049, -0.0638,  0.2572,  0.4358]], requires_grad=True)
# Parameter containing:
# tensor([0.4611], requires_grad=True)
# loss=0.856952428817749
# Parameter containing:
# tensor([[ 0.1500, -0.0640,  0.1007,  0.0288, -0.3170,  0.1088, -0.0027, -0.2976],
#         [ 0.0724, -0.2046,  0.1399, -0.0124, -0.2022, -0.0602,  0.3326, -0.3304],
#         [-0.1459,  0.3022, -0.1596, -0.1916,  0.0815, -0.0546,  0.1753,  0.2236],
#         [-0.2135, -0.3491,  0.0299, -0.0285, -0.2962,  0.3508,  0.2133, -0.1651],
#         [-0.1729, -0.1106,  0.1901,  0.3510, -0.3207,  0.3153, -0.3225, -0.2180],
#         [-0.3200, -0.2329, -0.2877, -0.1766,  0.1907,  0.1552,  0.1089, -0.0049]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2849,  0.3379,  0.3220, -0.3423, -0.2008,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3823, -0.2464, -0.2037, -0.0024, -0.0145,  0.4058],
#         [-0.2487,  0.2933,  0.3560, -0.2035, -0.2279,  0.2970],
#         [ 0.3403, -0.1067, -0.3537,  0.3600,  0.0933,  0.2990],
#         [ 0.0105, -0.1019, -0.0906,  0.2491, -0.1993,  0.3992]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2024,  0.2704, -0.3840,  0.3502], requires_grad=True)
# Parameter containing:
# tensor([[-0.1065, -0.0658,  0.2561,  0.4341]], requires_grad=True)
# Parameter containing:
# tensor([0.4579], requires_grad=True)
# loss=0.8548317551612854
# Parameter containing:
# tensor([[ 0.1500, -0.0642,  0.1006,  0.0288, -0.3170,  0.1088, -0.0027, -0.2976],
#         [ 0.0724, -0.2046,  0.1399, -0.0123, -0.2022, -0.0602,  0.3326, -0.3304],
#         [-0.1459,  0.3022, -0.1596, -0.1916,  0.0815, -0.0546,  0.1753,  0.2236],
#         [-0.2135, -0.3491,  0.0299, -0.0285, -0.2962,  0.3508,  0.2133, -0.1651],
#         [-0.1729, -0.1105,  0.1902,  0.3511, -0.3207,  0.3153, -0.3225, -0.2179],
#         [-0.3200, -0.2330, -0.2877, -0.1766,  0.1906,  0.1552,  0.1089, -0.0049]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2849,  0.3379,  0.3220, -0.3423, -0.2008,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3823, -0.2464, -0.2036, -0.0024, -0.0144,  0.4058],
#         [-0.2487,  0.2933,  0.3561, -0.2035, -0.2279,  0.2970],
#         [ 0.3402, -0.1067, -0.3539,  0.3600,  0.0933,  0.2990],
#         [ 0.0104, -0.1019, -0.0910,  0.2491, -0.1995,  0.3992]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2025,  0.2704, -0.3842,  0.3499], requires_grad=True)
# Parameter containing:
# tensor([[-0.1081, -0.0678,  0.2551,  0.4323]], requires_grad=True)
# Parameter containing:
# tensor([0.4547], requires_grad=True)
# loss=0.8527315258979797
# Parameter containing:
# tensor([[ 0.1500, -0.0644,  0.1004,  0.0287, -0.3170,  0.1087, -0.0027, -0.2977],
#         [ 0.0724, -0.2046,  0.1399, -0.0123, -0.2022, -0.0602,  0.3326, -0.3303],
#         [-0.1459,  0.3022, -0.1596, -0.1916,  0.0815, -0.0546,  0.1753,  0.2236],
#         [-0.2135, -0.3491,  0.0298, -0.0285, -0.2962,  0.3508,  0.2133, -0.1651],
#         [-0.1729, -0.1105,  0.1902,  0.3511, -0.3207,  0.3153, -0.3225, -0.2179],
#         [-0.3200, -0.2330, -0.2878, -0.1766,  0.1905,  0.1552,  0.1089, -0.0049]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2849,  0.3379,  0.3220, -0.3423, -0.2008,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3823, -0.2464, -0.2036, -0.0024, -0.0144,  0.4058],
#         [-0.2487,  0.2933,  0.3561, -0.2035, -0.2278,  0.2970],
#         [ 0.3402, -0.1067, -0.3540,  0.3600,  0.0932,  0.2990],
#         [ 0.0104, -0.1019, -0.0913,  0.2491, -0.1996,  0.3992]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2026,  0.2705, -0.3844,  0.3495], requires_grad=True)
# Parameter containing:
# tensor([[-0.1097, -0.0698,  0.2540,  0.4306]], requires_grad=True)
# Parameter containing:
# tensor([0.4516], requires_grad=True)
# loss=0.8506516814231873
# Parameter containing:
# tensor([[ 0.1500, -0.0645,  0.1003,  0.0287, -0.3170,  0.1086, -0.0027, -0.2977],
#         [ 0.0724, -0.2046,  0.1399, -0.0123, -0.2022, -0.0602,  0.3326, -0.3303],
#         [-0.1459,  0.3022, -0.1596, -0.1916,  0.0815, -0.0546,  0.1753,  0.2236],
#         [-0.2135, -0.3491,  0.0298, -0.0285, -0.2962,  0.3508,  0.2133, -0.1651],
#         [-0.1729, -0.1104,  0.1903,  0.3511, -0.3207,  0.3154, -0.3225, -0.2179],
#         [-0.3200, -0.2331, -0.2878, -0.1767,  0.1905,  0.1552,  0.1089, -0.0049]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2850,  0.3379,  0.3220, -0.3423, -0.2008,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3823, -0.2464, -0.2035, -0.0024, -0.0143,  0.4058],
#         [-0.2487,  0.2933,  0.3562, -0.2035, -0.2278,  0.2971],
#         [ 0.3402, -0.1067, -0.3542,  0.3600,  0.0931,  0.2990],
#         [ 0.0104, -0.1019, -0.0916,  0.2491, -0.1998,  0.3992]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2027,  0.2705, -0.3846,  0.3492], requires_grad=True)
# Parameter containing:
# tensor([[-0.1112, -0.0718,  0.2529,  0.4289]], requires_grad=True)
# Parameter containing:
# tensor([0.4484], requires_grad=True)
# loss=0.8485917448997498
# Parameter containing:
# tensor([[ 0.1500, -0.0647,  0.1002,  0.0287, -0.3170,  0.1086, -0.0027, -0.2977],
#         [ 0.0724, -0.2046,  0.1399, -0.0123, -0.2022, -0.0602,  0.3326, -0.3303],
#         [-0.1459,  0.3022, -0.1596, -0.1916,  0.0815, -0.0546,  0.1753,  0.2236],
#         [-0.2135, -0.3491,  0.0298, -0.0285, -0.2962,  0.3508,  0.2133, -0.1651],
#         [-0.1729, -0.1103,  0.1903,  0.3511, -0.3207,  0.3154, -0.3225, -0.2179],
#         [-0.3200, -0.2331, -0.2878, -0.1767,  0.1904,  0.1552,  0.1089, -0.0049]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2850,  0.3379,  0.3220, -0.3423, -0.2008,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3823, -0.2464, -0.2034, -0.0024, -0.0143,  0.4059],
#         [-0.2487,  0.2933,  0.3562, -0.2035, -0.2278,  0.2971],
#         [ 0.3402, -0.1067, -0.3544,  0.3600,  0.0930,  0.2990],
#         [ 0.0104, -0.1019, -0.0920,  0.2491, -0.1999,  0.3991]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2028,  0.2706, -0.3848,  0.3489], requires_grad=True)
# Parameter containing:
# tensor([[-0.1128, -0.0737,  0.2519,  0.4272]], requires_grad=True)
# Parameter containing:
# tensor([0.4453], requires_grad=True)
# loss=0.8465516567230225
# Parameter containing:
# tensor([[ 0.1500, -0.0648,  0.1000,  0.0286, -0.3170,  0.1085, -0.0027, -0.2978],
#         [ 0.0724, -0.2046,  0.1400, -0.0123, -0.2022, -0.0602,  0.3326, -0.3303],
#         [-0.1459,  0.3022, -0.1596, -0.1916,  0.0815, -0.0546,  0.1753,  0.2236],
#         [-0.2135, -0.3491,  0.0298, -0.0285, -0.2962,  0.3508,  0.2133, -0.1651],
#         [-0.1729, -0.1102,  0.1904,  0.3511, -0.3206,  0.3154, -0.3225, -0.2178],
#         [-0.3200, -0.2331, -0.2878, -0.1767,  0.1903,  0.1552,  0.1089, -0.0049]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2850,  0.3379,  0.3220, -0.3423, -0.2008,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3823, -0.2464, -0.2033, -0.0024, -0.0143,  0.4059],
#         [-0.2487,  0.2933,  0.3563, -0.2035, -0.2278,  0.2971],
#         [ 0.3402, -0.1067, -0.3546,  0.3600,  0.0929,  0.2990],
#         [ 0.0104, -0.1019, -0.0923,  0.2491, -0.2001,  0.3991]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2029,  0.2706, -0.3849,  0.3485], requires_grad=True)
# Parameter containing:
# tensor([[-0.1143, -0.0757,  0.2508,  0.4255]], requires_grad=True)
# Parameter containing:
# tensor([0.4422], requires_grad=True)
# loss=0.8445315361022949
# Parameter containing:
# tensor([[ 0.1500, -0.0650,  0.0999,  0.0286, -0.3170,  0.1085, -0.0027, -0.2978],
#         [ 0.0724, -0.2046,  0.1400, -0.0123, -0.2022, -0.0602,  0.3326, -0.3303],
#         [-0.1459,  0.3022, -0.1596, -0.1916,  0.0815, -0.0546,  0.1753,  0.2236],
#         [-0.2135, -0.3491,  0.0298, -0.0285, -0.2962,  0.3508,  0.2133, -0.1651],
#         [-0.1729, -0.1101,  0.1904,  0.3511, -0.3206,  0.3154, -0.3225, -0.2178],
#         [-0.3200, -0.2331, -0.2878, -0.1767,  0.1903,  0.1552,  0.1089, -0.0049]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2850,  0.3379,  0.3220, -0.3423, -0.2008,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3823, -0.2464, -0.2032, -0.0024, -0.0142,  0.4059],
#         [-0.2487,  0.2933,  0.3564, -0.2035, -0.2277,  0.2971],
#         [ 0.3402, -0.1067, -0.3547,  0.3600,  0.0929,  0.2989],
#         [ 0.0104, -0.1019, -0.0926,  0.2491, -0.2002,  0.3991]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2030,  0.2707, -0.3851,  0.3482], requires_grad=True)
# Parameter containing:
# tensor([[-0.1159, -0.0776,  0.2498,  0.4238]], requires_grad=True)
# Parameter containing:
# tensor([0.4391], requires_grad=True)
# loss=0.8425307273864746
# Parameter containing:
# tensor([[ 0.1500, -0.0651,  0.0998,  0.0286, -0.3170,  0.1084, -0.0027, -0.2979],
#         [ 0.0724, -0.2046,  0.1400, -0.0123, -0.2022, -0.0602,  0.3326, -0.3303],
#         [-0.1459,  0.3022, -0.1596, -0.1916,  0.0815, -0.0546,  0.1753,  0.2236],
#         [-0.2135, -0.3491,  0.0298, -0.0285, -0.2962,  0.3508,  0.2133, -0.1651],
#         [-0.1729, -0.1101,  0.1905,  0.3511, -0.3206,  0.3154, -0.3225, -0.2178],
#         [-0.3200, -0.2332, -0.2878, -0.1767,  0.1902,  0.1552,  0.1089, -0.0049]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2850,  0.3379,  0.3220, -0.3423, -0.2008,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3823, -0.2464, -0.2031, -0.0024, -0.0142,  0.4059],
#         [-0.2487,  0.2933,  0.3564, -0.2035, -0.2277,  0.2971],
#         [ 0.3402, -0.1067, -0.3549,  0.3600,  0.0928,  0.2989],
#         [ 0.0104, -0.1019, -0.0929,  0.2491, -0.2004,  0.3991]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2030,  0.2707, -0.3853,  0.3479], requires_grad=True)
# Parameter containing:
# tensor([[-0.1174, -0.0796,  0.2488,  0.4221]], requires_grad=True)
# Parameter containing:
# tensor([0.4360], requires_grad=True)
# loss=0.8405494689941406
# Parameter containing:
# tensor([[ 0.1500, -0.0653,  0.0997,  0.0285, -0.3170,  0.1084, -0.0027, -0.2979],
#         [ 0.0724, -0.2046,  0.1400, -0.0123, -0.2022, -0.0602,  0.3326, -0.3303],
#         [-0.1459,  0.3022, -0.1596, -0.1916,  0.0815, -0.0546,  0.1753,  0.2236],
#         [-0.2135, -0.3491,  0.0298, -0.0285, -0.2962,  0.3508,  0.2133, -0.1651],
#         [-0.1729, -0.1100,  0.1905,  0.3511, -0.3206,  0.3155, -0.3225, -0.2178],
#         [-0.3200, -0.2332, -0.2879, -0.1767,  0.1902,  0.1552,  0.1089, -0.0049]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2850,  0.3379,  0.3220, -0.3423, -0.2008,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3823, -0.2464, -0.2030, -0.0024, -0.0141,  0.4059],
#         [-0.2487,  0.2933,  0.3565, -0.2035, -0.2277,  0.2971],
#         [ 0.3402, -0.1067, -0.3551,  0.3600,  0.0927,  0.2989],
#         [ 0.0104, -0.1019, -0.0933,  0.2491, -0.2005,  0.3991]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2031,  0.2708, -0.3854,  0.3476], requires_grad=True)
# Parameter containing:
# tensor([[-0.1190, -0.0815,  0.2477,  0.4205]], requires_grad=True)
# Parameter containing:
# tensor([0.4330], requires_grad=True)
# loss=0.8385874629020691
# Parameter containing:
# tensor([[ 0.1500, -0.0654,  0.0996,  0.0285, -0.3170,  0.1083, -0.0027, -0.2979],
#         [ 0.0724, -0.2046,  0.1400, -0.0123, -0.2022, -0.0602,  0.3326, -0.3303],
#         [-0.1459,  0.3022, -0.1596, -0.1916,  0.0815, -0.0546,  0.1753,  0.2236],
#         [-0.2135, -0.3491,  0.0298, -0.0285, -0.2962,  0.3508,  0.2133, -0.1651],
#         [-0.1729, -0.1099,  0.1906,  0.3511, -0.3206,  0.3155, -0.3225, -0.2177],
#         [-0.3200, -0.2332, -0.2879, -0.1767,  0.1901,  0.1552,  0.1089, -0.0049]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2850,  0.3379,  0.3220, -0.3423, -0.2008,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3823, -0.2464, -0.2029, -0.0024, -0.0141,  0.4059],
#         [-0.2487,  0.2933,  0.3565, -0.2035, -0.2277,  0.2971],
#         [ 0.3402, -0.1067, -0.3552,  0.3600,  0.0926,  0.2989],
#         [ 0.0104, -0.1019, -0.0936,  0.2491, -0.2007,  0.3991]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2032,  0.2709, -0.3856,  0.3472], requires_grad=True)
# Parameter containing:
# tensor([[-0.1205, -0.0834,  0.2467,  0.4188]], requires_grad=True)
# Parameter containing:
# tensor([0.4299], requires_grad=True)
# loss=0.8366444706916809
# Parameter containing:
# tensor([[ 0.1500, -0.0656,  0.0994,  0.0285, -0.3170,  0.1083, -0.0027, -0.2980],
#         [ 0.0724, -0.2046,  0.1400, -0.0123, -0.2022, -0.0602,  0.3326, -0.3303],
#         [-0.1459,  0.3022, -0.1596, -0.1916,  0.0815, -0.0546,  0.1753,  0.2236],
#         [-0.2135, -0.3491,  0.0298, -0.0285, -0.2962,  0.3507,  0.2133, -0.1651],
#         [-0.1729, -0.1098,  0.1906,  0.3511, -0.3206,  0.3155, -0.3225, -0.2177],
#         [-0.3200, -0.2333, -0.2879, -0.1767,  0.1900,  0.1551,  0.1089, -0.0049]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2850,  0.3379,  0.3220, -0.3423, -0.2008,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3823, -0.2464, -0.2029, -0.0024, -0.0141,  0.4059],
#         [-0.2487,  0.2933,  0.3566, -0.2035, -0.2276,  0.2971],
#         [ 0.3402, -0.1067, -0.3554,  0.3600,  0.0926,  0.2989],
#         [ 0.0104, -0.1019, -0.0939,  0.2491, -0.2008,  0.3991]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2033,  0.2709, -0.3858,  0.3469], requires_grad=True)
# Parameter containing:
# tensor([[-0.1220, -0.0853,  0.2457,  0.4171]], requires_grad=True)
# Parameter containing:
# tensor([0.4269], requires_grad=True)
# loss=0.8347203731536865
# Parameter containing:
# tensor([[ 0.1499, -0.0657,  0.0993,  0.0284, -0.3170,  0.1083, -0.0027, -0.2980],
#         [ 0.0724, -0.2046,  0.1400, -0.0123, -0.2022, -0.0602,  0.3326, -0.3303],
#         [-0.1459,  0.3022, -0.1596, -0.1916,  0.0815, -0.0546,  0.1753,  0.2236],
#         [-0.2135, -0.3491,  0.0298, -0.0285, -0.2962,  0.3507,  0.2133, -0.1651],
#         [-0.1729, -0.1098,  0.1907,  0.3512, -0.3206,  0.3155, -0.3225, -0.2177],
#         [-0.3200, -0.2333, -0.2879, -0.1767,  0.1900,  0.1551,  0.1089, -0.0049]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2850,  0.3379,  0.3220, -0.3423, -0.2008,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3823, -0.2464, -0.2028, -0.0024, -0.0140,  0.4059],
#         [-0.2487,  0.2933,  0.3566, -0.2035, -0.2276,  0.2971],
#         [ 0.3402, -0.1067, -0.3556,  0.3600,  0.0925,  0.2989],
#         [ 0.0104, -0.1019, -0.0942,  0.2491, -0.2009,  0.3991]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2034,  0.2710, -0.3859,  0.3466], requires_grad=True)
# Parameter containing:
# tensor([[-0.1235, -0.0872,  0.2447,  0.4155]], requires_grad=True)
# Parameter containing:
# tensor([0.4239], requires_grad=True)
# loss=0.8328151702880859
# Parameter containing:
# tensor([[ 0.1499, -0.0658,  0.0992,  0.0284, -0.3170,  0.1082, -0.0027, -0.2981],
#         [ 0.0724, -0.2046,  0.1400, -0.0123, -0.2022, -0.0602,  0.3326, -0.3303],
#         [-0.1459,  0.3022, -0.1596, -0.1916,  0.0815, -0.0546,  0.1753,  0.2236],
#         [-0.2135, -0.3491,  0.0298, -0.0285, -0.2962,  0.3507,  0.2133, -0.1651],
#         [-0.1729, -0.1097,  0.1907,  0.3512, -0.3205,  0.3155, -0.3225, -0.2177],
#         [-0.3200, -0.2333, -0.2879, -0.1767,  0.1899,  0.1551,  0.1089, -0.0049]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2850,  0.3379,  0.3220, -0.3423, -0.2008,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3823, -0.2464, -0.2027, -0.0024, -0.0140,  0.4059],
#         [-0.2487,  0.2933,  0.3567, -0.2035, -0.2276,  0.2971],
#         [ 0.3402, -0.1067, -0.3557,  0.3600,  0.0924,  0.2989],
#         [ 0.0104, -0.1019, -0.0945,  0.2491, -0.2011,  0.3991]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2035,  0.2710, -0.3861,  0.3463], requires_grad=True)
# Parameter containing:
# tensor([[-0.1250, -0.0891,  0.2436,  0.4139]], requires_grad=True)
# Parameter containing:
# tensor([0.4209], requires_grad=True)
# loss=0.8309283256530762
# Parameter containing:
# tensor([[ 0.1499, -0.0660,  0.0991,  0.0284, -0.3170,  0.1082, -0.0027, -0.2981],
#         [ 0.0724, -0.2046,  0.1400, -0.0123, -0.2022, -0.0602,  0.3326, -0.3303],
#         [-0.1459,  0.3022, -0.1596, -0.1916,  0.0815, -0.0546,  0.1753,  0.2236],
#         [-0.2135, -0.3491,  0.0298, -0.0285, -0.2962,  0.3507,  0.2133, -0.1651],
#         [-0.1729, -0.1096,  0.1908,  0.3512, -0.3205,  0.3156, -0.3225, -0.2177],
#         [-0.3200, -0.2333, -0.2879, -0.1767,  0.1899,  0.1551,  0.1089, -0.0049]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2850,  0.3379,  0.3220, -0.3423, -0.2008,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3823, -0.2464, -0.2026, -0.0024, -0.0139,  0.4059],
#         [-0.2487,  0.2933,  0.3568, -0.2035, -0.2275,  0.2971],
#         [ 0.3402, -0.1067, -0.3559,  0.3600,  0.0923,  0.2989],
#         [ 0.0104, -0.1019, -0.0948,  0.2491, -0.2012,  0.3991]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2036,  0.2711, -0.3863,  0.3460], requires_grad=True)
# Parameter containing:
# tensor([[-0.1265, -0.0910,  0.2426,  0.4122]], requires_grad=True)
# Parameter containing:
# tensor([0.4179], requires_grad=True)
# loss=0.8290600776672363
# Parameter containing:
# tensor([[ 0.1499, -0.0661,  0.0990,  0.0284, -0.3170,  0.1081, -0.0027, -0.2981],
#         [ 0.0724, -0.2046,  0.1400, -0.0123, -0.2022, -0.0602,  0.3326, -0.3303],
#         [-0.1459,  0.3022, -0.1596, -0.1916,  0.0815, -0.0546,  0.1753,  0.2236],
#         [-0.2135, -0.3491,  0.0298, -0.0285, -0.2962,  0.3507,  0.2133, -0.1651],
#         [-0.1729, -0.1096,  0.1908,  0.3512, -0.3205,  0.3156, -0.3225, -0.2176],
#         [-0.3200, -0.2334, -0.2880, -0.1767,  0.1898,  0.1551,  0.1089, -0.0049]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2850,  0.3379,  0.3220, -0.3423, -0.2008,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3823, -0.2464, -0.2025, -0.0024, -0.0139,  0.4059],
#         [-0.2487,  0.2933,  0.3568, -0.2035, -0.2275,  0.2971],
#         [ 0.3402, -0.1067, -0.3561,  0.3600,  0.0923,  0.2989],
#         [ 0.0104, -0.1019, -0.0951,  0.2491, -0.2014,  0.3990]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2037,  0.2712, -0.3864,  0.3457], requires_grad=True)
# Parameter containing:
# tensor([[-0.1280, -0.0929,  0.2416,  0.4106]], requires_grad=True)
# Parameter containing:
# tensor([0.4149], requires_grad=True)
# loss=0.8272101283073425
# Parameter containing:
# tensor([[ 0.1499, -0.0662,  0.0989,  0.0283, -0.3170,  0.1081, -0.0027, -0.2982],
#         [ 0.0724, -0.2046,  0.1400, -0.0123, -0.2022, -0.0602,  0.3326, -0.3303],
#         [-0.1459,  0.3022, -0.1596, -0.1916,  0.0815, -0.0546,  0.1753,  0.2236],
#         [-0.2135, -0.3491,  0.0297, -0.0285, -0.2962,  0.3507,  0.2133, -0.1651],
#         [-0.1728, -0.1095,  0.1908,  0.3512, -0.3205,  0.3156, -0.3225, -0.2176],
#         [-0.3200, -0.2334, -0.2880, -0.1767,  0.1898,  0.1551,  0.1089, -0.0049]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2850,  0.3379,  0.3220, -0.3423, -0.2008,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3823, -0.2464, -0.2024, -0.0024, -0.0139,  0.4059],
#         [-0.2487,  0.2933,  0.3569, -0.2035, -0.2275,  0.2971],
#         [ 0.3402, -0.1067, -0.3562,  0.3600,  0.0922,  0.2989],
#         [ 0.0103, -0.1019, -0.0954,  0.2491, -0.2015,  0.3990]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2038,  0.2712, -0.3866,  0.3454], requires_grad=True)
# Parameter containing:
# tensor([[-0.1295, -0.0947,  0.2406,  0.4090]], requires_grad=True)
# Parameter containing:
# tensor([0.4119], requires_grad=True)
# loss=0.8253781199455261
# Parameter containing:
# tensor([[ 0.1499, -0.0664,  0.0988,  0.0283, -0.3170,  0.1080, -0.0027, -0.2982],
#         [ 0.0724, -0.2046,  0.1400, -0.0123, -0.2022, -0.0602,  0.3326, -0.3303],
#         [-0.1459,  0.3022, -0.1596, -0.1916,  0.0815, -0.0546,  0.1753,  0.2236],
#         [-0.2135, -0.3491,  0.0297, -0.0285, -0.2962,  0.3507,  0.2133, -0.1651],
#         [-0.1728, -0.1095,  0.1909,  0.3512, -0.3205,  0.3156, -0.3225, -0.2176],
#         [-0.3200, -0.2334, -0.2880, -0.1767,  0.1897,  0.1551,  0.1089, -0.0049]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2850,  0.3379,  0.3220, -0.3423, -0.2008,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3823, -0.2464, -0.2023, -0.0024, -0.0138,  0.4059],
#         [-0.2487,  0.2933,  0.3570, -0.2035, -0.2275,  0.2971],
#         [ 0.3402, -0.1067, -0.3564,  0.3600,  0.0921,  0.2989],
#         [ 0.0103, -0.1019, -0.0957,  0.2491, -0.2016,  0.3990]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2039,  0.2713, -0.3867,  0.3451], requires_grad=True)
# Parameter containing:
# tensor([[-0.1310, -0.0966,  0.2396,  0.4074]], requires_grad=True)
# Parameter containing:
# tensor([0.4090], requires_grad=True)
# loss=0.8235641121864319
# Parameter containing:
# tensor([[ 0.1499, -0.0665,  0.0987,  0.0283, -0.3170,  0.1080, -0.0027, -0.2982],
#         [ 0.0724, -0.2046,  0.1400, -0.0123, -0.2022, -0.0602,  0.3326, -0.3303],
#         [-0.1459,  0.3022, -0.1596, -0.1916,  0.0815, -0.0546,  0.1753,  0.2236],
#         [-0.2135, -0.3491,  0.0297, -0.0285, -0.2962,  0.3507,  0.2133, -0.1651],
#         [-0.1728, -0.1094,  0.1909,  0.3512, -0.3205,  0.3156, -0.3225, -0.2176],
#         [-0.3200, -0.2334, -0.2880, -0.1767,  0.1897,  0.1551,  0.1089, -0.0049]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2850,  0.3379,  0.3220, -0.3423, -0.2008,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3823, -0.2464, -0.2022, -0.0024, -0.0138,  0.4059],
#         [-0.2487,  0.2933,  0.3570, -0.2035, -0.2274,  0.2971],
#         [ 0.3402, -0.1067, -0.3565,  0.3600,  0.0920,  0.2989],
#         [ 0.0103, -0.1019, -0.0960,  0.2491, -0.2018,  0.3990]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2040,  0.2714, -0.3869,  0.3448], requires_grad=True)
# Parameter containing:
# tensor([[-0.1324, -0.0984,  0.2387,  0.4058]], requires_grad=True)
# Parameter containing:
# tensor([0.4060], requires_grad=True)
# loss=0.821768045425415
# Parameter containing:
# tensor([[ 0.1499, -0.0666,  0.0986,  0.0283, -0.3170,  0.1079, -0.0027, -0.2983],
#         [ 0.0724, -0.2046,  0.1400, -0.0123, -0.2022, -0.0602,  0.3326, -0.3303],
#         [-0.1459,  0.3022, -0.1596, -0.1916,  0.0815, -0.0546,  0.1753,  0.2236],
#         [-0.2135, -0.3491,  0.0297, -0.0285, -0.2962,  0.3507,  0.2133, -0.1651],
#         [-0.1728, -0.1093,  0.1910,  0.3512, -0.3205,  0.3156, -0.3225, -0.2176],
#         [-0.3200, -0.2335, -0.2880, -0.1767,  0.1896,  0.1551,  0.1089, -0.0049]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2850,  0.3379,  0.3220, -0.3423, -0.2008,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3823, -0.2464, -0.2021, -0.0024, -0.0137,  0.4059],
#         [-0.2487,  0.2933,  0.3571, -0.2035, -0.2274,  0.2971],
#         [ 0.3402, -0.1067, -0.3567,  0.3600,  0.0920,  0.2989],
#         [ 0.0103, -0.1019, -0.0963,  0.2491, -0.2019,  0.3990]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2041,  0.2714, -0.3871,  0.3445], requires_grad=True)
# Parameter containing:
# tensor([[-0.1339, -0.1003,  0.2377,  0.4042]], requires_grad=True)
# Parameter containing:
# tensor([0.4031], requires_grad=True)
# loss=0.8199895024299622
# Parameter containing:
# tensor([[ 0.1499, -0.0668,  0.0985,  0.0282, -0.3170,  0.1079, -0.0027, -0.2983],
#         [ 0.0724, -0.2046,  0.1400, -0.0123, -0.2022, -0.0602,  0.3326, -0.3303],
#         [-0.1459,  0.3022, -0.1596, -0.1916,  0.0815, -0.0546,  0.1753,  0.2236],
#         [-0.2135, -0.3491,  0.0297, -0.0285, -0.2962,  0.3507,  0.2133, -0.1651],
#         [-0.1728, -0.1093,  0.1910,  0.3512, -0.3204,  0.3157, -0.3225, -0.2175],
#         [-0.3200, -0.2335, -0.2880, -0.1767,  0.1896,  0.1551,  0.1089, -0.0050]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2850,  0.3379,  0.3220, -0.3423, -0.2008,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3823, -0.2464, -0.2020, -0.0024, -0.0137,  0.4059],
#         [-0.2487,  0.2933,  0.3572, -0.2035, -0.2274,  0.2971],
#         [ 0.3402, -0.1067, -0.3568,  0.3600,  0.0919,  0.2989],
#         [ 0.0103, -0.1019, -0.0966,  0.2491, -0.2020,  0.3990]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2042,  0.2715, -0.3872,  0.3442], requires_grad=True)
# Parameter containing:
# tensor([[-0.1354, -0.1021,  0.2367,  0.4026]], requires_grad=True)
# Parameter containing:
# tensor([0.4002], requires_grad=True)
# loss=0.8182284235954285
# Parameter containing:
# tensor([[ 0.1499, -0.0669,  0.0984,  0.0282, -0.3170,  0.1079, -0.0027, -0.2983],
#         [ 0.0724, -0.2046,  0.1400, -0.0123, -0.2022, -0.0602,  0.3326, -0.3303],
#         [-0.1459,  0.3022, -0.1596, -0.1916,  0.0815, -0.0546,  0.1753,  0.2236],
#         [-0.2135, -0.3491,  0.0297, -0.0285, -0.2962,  0.3507,  0.2133, -0.1651],
#         [-0.1728, -0.1092,  0.1910,  0.3512, -0.3204,  0.3157, -0.3225, -0.2175],
#         [-0.3200, -0.2335, -0.2880, -0.1767,  0.1895,  0.1551,  0.1089, -0.0050]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2850,  0.3379,  0.3220, -0.3423, -0.2008,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3823, -0.2464, -0.2019, -0.0024, -0.0136,  0.4059],
#         [-0.2487,  0.2933,  0.3572, -0.2035, -0.2273,  0.2971],
#         [ 0.3402, -0.1067, -0.3570,  0.3600,  0.0918,  0.2989],
#         [ 0.0103, -0.1019, -0.0969,  0.2491, -0.2022,  0.3990]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2043,  0.2716, -0.3874,  0.3439], requires_grad=True)
# Parameter containing:
# tensor([[-0.1368, -0.1039,  0.2357,  0.4011]], requires_grad=True)
# Parameter containing:
# tensor([0.3973], requires_grad=True)
# loss=0.8164848685264587
# Parameter containing:
# tensor([[ 0.1499, -0.0670,  0.0983,  0.0282, -0.3170,  0.1078, -0.0027, -0.2984],
#         [ 0.0724, -0.2046,  0.1400, -0.0123, -0.2022, -0.0602,  0.3326, -0.3303],
#         [-0.1459,  0.3022, -0.1596, -0.1916,  0.0815, -0.0546,  0.1753,  0.2236],
#         [-0.2135, -0.3491,  0.0297, -0.0285, -0.2962,  0.3507,  0.2133, -0.1651],
#         [-0.1728, -0.1092,  0.1911,  0.3512, -0.3204,  0.3157, -0.3225, -0.2175],
#         [-0.3200, -0.2335, -0.2880, -0.1767,  0.1895,  0.1551,  0.1089, -0.0050]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2850,  0.3379,  0.3220, -0.3423, -0.2008,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3823, -0.2464, -0.2018, -0.0024, -0.0136,  0.4059],
#         [-0.2487,  0.2933,  0.3573, -0.2035, -0.2273,  0.2971],
#         [ 0.3402, -0.1067, -0.3571,  0.3600,  0.0918,  0.2989],
#         [ 0.0103, -0.1019, -0.0972,  0.2491, -0.2023,  0.3990]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2044,  0.2716, -0.3875,  0.3437], requires_grad=True)
# Parameter containing:
# tensor([[-0.1382, -0.1057,  0.2348,  0.3995]], requires_grad=True)
# Parameter containing:
# tensor([0.3945], requires_grad=True)
# loss=0.8147582411766052
# Parameter containing:
# tensor([[ 0.1499, -0.0671,  0.0982,  0.0281, -0.3170,  0.1078, -0.0027, -0.2984],
#         [ 0.0724, -0.2046,  0.1400, -0.0123, -0.2022, -0.0602,  0.3326, -0.3303],
#         [-0.1459,  0.3022, -0.1596, -0.1916,  0.0815, -0.0546,  0.1753,  0.2236],
#         [-0.2135, -0.3491,  0.0297, -0.0286, -0.2963,  0.3507,  0.2133, -0.1651],
#         [-0.1728, -0.1091,  0.1911,  0.3512, -0.3204,  0.3157, -0.3225, -0.2175],
#         [-0.3200, -0.2336, -0.2881, -0.1768,  0.1894,  0.1551,  0.1089, -0.0050]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2850,  0.3379,  0.3220, -0.3423, -0.2008,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3823, -0.2464, -0.2017, -0.0024, -0.0135,  0.4059],
#         [-0.2487,  0.2933,  0.3574, -0.2035, -0.2273,  0.2971],
#         [ 0.3402, -0.1067, -0.3573,  0.3600,  0.0917,  0.2988],
#         [ 0.0103, -0.1019, -0.0974,  0.2491, -0.2024,  0.3990]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2045,  0.2717, -0.3877,  0.3434], requires_grad=True)
# Parameter containing:
# tensor([[-0.1397, -0.1075,  0.2338,  0.3980]], requires_grad=True)
# Parameter containing:
# tensor([0.3916], requires_grad=True)
# loss=0.813048779964447
# Parameter containing:
# tensor([[ 0.1499, -0.0672,  0.0981,  0.0281, -0.3170,  0.1077, -0.0027, -0.2984],
#         [ 0.0724, -0.2046,  0.1400, -0.0123, -0.2022, -0.0602,  0.3326, -0.3303],
#         [-0.1459,  0.3022, -0.1596, -0.1916,  0.0815, -0.0546,  0.1753,  0.2236],
#         [-0.2135, -0.3491,  0.0297, -0.0286, -0.2963,  0.3507,  0.2133, -0.1651],
#         [-0.1728, -0.1091,  0.1912,  0.3512, -0.3204,  0.3157, -0.3225, -0.2175],
#         [-0.3200, -0.2336, -0.2881, -0.1768,  0.1894,  0.1551,  0.1089, -0.0050]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2850,  0.3379,  0.3220, -0.3423, -0.2008,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3823, -0.2464, -0.2016, -0.0024, -0.0135,  0.4059],
#         [-0.2486,  0.2933,  0.3574, -0.2035, -0.2272,  0.2971],
#         [ 0.3402, -0.1067, -0.3574,  0.3600,  0.0916,  0.2988],
#         [ 0.0103, -0.1019, -0.0977,  0.2491, -0.2025,  0.3990]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2046,  0.2718, -0.3878,  0.3431], requires_grad=True)
# Parameter containing:
# tensor([[-0.1411, -0.1093,  0.2328,  0.3964]], requires_grad=True)
# Parameter containing:
# tensor([0.3887], requires_grad=True)
# loss=0.8113560676574707
# Parameter containing:
# tensor([[ 0.1499, -0.0673,  0.0980,  0.0281, -0.3170,  0.1077, -0.0027, -0.2985],
#         [ 0.0724, -0.2046,  0.1400, -0.0123, -0.2022, -0.0602,  0.3326, -0.3303],
#         [-0.1459,  0.3022, -0.1596, -0.1916,  0.0815, -0.0546,  0.1753,  0.2236],
#         [-0.2135, -0.3491,  0.0297, -0.0286, -0.2963,  0.3507,  0.2133, -0.1651],
#         [-0.1728, -0.1090,  0.1912,  0.3513, -0.3204,  0.3157, -0.3225, -0.2175],
#         [-0.3200, -0.2336, -0.2881, -0.1768,  0.1894,  0.1551,  0.1089, -0.0050]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2850,  0.3379,  0.3220, -0.3423, -0.2008,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3823, -0.2464, -0.2015, -0.0024, -0.0135,  0.4059],
#         [-0.2486,  0.2933,  0.3575, -0.2035, -0.2272,  0.2971],
#         [ 0.3402, -0.1067, -0.3576,  0.3600,  0.0916,  0.2988],
#         [ 0.0103, -0.1019, -0.0980,  0.2491, -0.2027,  0.3990]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2047,  0.2718, -0.3880,  0.3428], requires_grad=True)
# Parameter containing:
# tensor([[-0.1425, -0.1111,  0.2319,  0.3949]], requires_grad=True)
# Parameter containing:
# tensor([0.3859], requires_grad=True)
# loss=0.8096804022789001
# Parameter containing:
# tensor([[ 0.1499, -0.0675,  0.0979,  0.0281, -0.3170,  0.1077, -0.0027, -0.2985],
#         [ 0.0724, -0.2046,  0.1400, -0.0123, -0.2022, -0.0602,  0.3326, -0.3303],
#         [-0.1459,  0.3022, -0.1596, -0.1916,  0.0815, -0.0546,  0.1753,  0.2236],
#         [-0.2135, -0.3491,  0.0297, -0.0286, -0.2963,  0.3507,  0.2133, -0.1651],
#         [-0.1728, -0.1090,  0.1912,  0.3513, -0.3204,  0.3158, -0.3225, -0.2174],
#         [-0.3200, -0.2336, -0.2881, -0.1768,  0.1893,  0.1550,  0.1089, -0.0050]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2850,  0.3379,  0.3220, -0.3423, -0.2008,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3823, -0.2464, -0.2014, -0.0024, -0.0134,  0.4059],
#         [-0.2486,  0.2933,  0.3576, -0.2035, -0.2272,  0.2971],
#         [ 0.3402, -0.1067, -0.3577,  0.3600,  0.0915,  0.2988],
#         [ 0.0103, -0.1019, -0.0983,  0.2491, -0.2028,  0.3989]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2048,  0.2719, -0.3881,  0.3425], requires_grad=True)
# Parameter containing:
# tensor([[-0.1439, -0.1129,  0.2309,  0.3934]], requires_grad=True)
# Parameter containing:
# tensor([0.3831], requires_grad=True)
# loss=0.808021068572998
# Parameter containing:
# tensor([[ 0.1499, -0.0676,  0.0978,  0.0280, -0.3170,  0.1076, -0.0027, -0.2985],
#         [ 0.0724, -0.2046,  0.1400, -0.0123, -0.2022, -0.0602,  0.3326, -0.3303],
#         [-0.1459,  0.3022, -0.1596, -0.1916,  0.0815, -0.0546,  0.1753,  0.2236],
#         [-0.2135, -0.3491,  0.0297, -0.0286, -0.2963,  0.3507,  0.2133, -0.1651],
#         [-0.1728, -0.1089,  0.1913,  0.3513, -0.3204,  0.3158, -0.3225, -0.2174],
#         [-0.3200, -0.2336, -0.2881, -0.1768,  0.1893,  0.1550,  0.1089, -0.0050]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2850,  0.3379,  0.3220, -0.3423, -0.2008,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3823, -0.2464, -0.2013, -0.0024, -0.0134,  0.4059],
#         [-0.2486,  0.2933,  0.3576, -0.2035, -0.2271,  0.2971],
#         [ 0.3402, -0.1067, -0.3579,  0.3600,  0.0914,  0.2988],
#         [ 0.0103, -0.1019, -0.0985,  0.2491, -0.2029,  0.3989]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2049,  0.2720, -0.3883,  0.3423], requires_grad=True)
# Parameter containing:
# tensor([[-0.1454, -0.1146,  0.2300,  0.3918]], requires_grad=True)
# Parameter containing:
# tensor([0.3803], requires_grad=True)
# loss=0.806378185749054
# Parameter containing:
# tensor([[ 0.1499, -0.0677,  0.0977,  0.0280, -0.3170,  0.1076, -0.0027, -0.2986],
#         [ 0.0724, -0.2046,  0.1400, -0.0123, -0.2022, -0.0602,  0.3326, -0.3303],
#         [-0.1459,  0.3022, -0.1596, -0.1916,  0.0815, -0.0546,  0.1753,  0.2236],
#         [-0.2135, -0.3491,  0.0297, -0.0286, -0.2963,  0.3507,  0.2133, -0.1651],
#         [-0.1728, -0.1089,  0.1913,  0.3513, -0.3203,  0.3158, -0.3225, -0.2174],
#         [-0.3200, -0.2337, -0.2881, -0.1768,  0.1892,  0.1550,  0.1089, -0.0050]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2850,  0.3379,  0.3220, -0.3423, -0.2008,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3823, -0.2464, -0.2012, -0.0024, -0.0133,  0.4059],
#         [-0.2486,  0.2933,  0.3577, -0.2035, -0.2271,  0.2971],
#         [ 0.3402, -0.1067, -0.3580,  0.3600,  0.0914,  0.2988],
#         [ 0.0103, -0.1019, -0.0988,  0.2491, -0.2031,  0.3989]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2050,  0.2721, -0.3884,  0.3420], requires_grad=True)
# Parameter containing:
# tensor([[-0.1468, -0.1164,  0.2291,  0.3903]], requires_grad=True)
# Parameter containing:
# tensor([0.3775], requires_grad=True)
# loss=0.8047516942024231
# Parameter containing:
# tensor([[ 0.1499, -0.0678,  0.0976,  0.0280, -0.3170,  0.1075, -0.0027, -0.2986],
#         [ 0.0724, -0.2046,  0.1400, -0.0123, -0.2022, -0.0602,  0.3326, -0.3303],
#         [-0.1459,  0.3022, -0.1596, -0.1916,  0.0815, -0.0546,  0.1753,  0.2236],
#         [-0.2135, -0.3491,  0.0297, -0.0286, -0.2963,  0.3507,  0.2133, -0.1651],
#         [-0.1728, -0.1088,  0.1913,  0.3513, -0.3203,  0.3158, -0.3225, -0.2174],
#         [-0.3200, -0.2337, -0.2881, -0.1768,  0.1892,  0.1550,  0.1089, -0.0050]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2850,  0.3379,  0.3220, -0.3423, -0.2008,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3823, -0.2464, -0.2011, -0.0024, -0.0133,  0.4059],
#         [-0.2486,  0.2933,  0.3578, -0.2035, -0.2271,  0.2971],
#         [ 0.3402, -0.1067, -0.3581,  0.3600,  0.0913,  0.2988],
#         [ 0.0103, -0.1019, -0.0991,  0.2491, -0.2032,  0.3989]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2051,  0.2721, -0.3885,  0.3417], requires_grad=True)
# Parameter containing:
# tensor([[-0.1481, -0.1181,  0.2281,  0.3888]], requires_grad=True)
# Parameter containing:
# tensor([0.3747], requires_grad=True)
# loss=0.8031412959098816
# Parameter containing:
# tensor([[ 0.1499, -0.0679,  0.0975,  0.0280, -0.3170,  0.1075, -0.0027, -0.2986],
#         [ 0.0724, -0.2046,  0.1400, -0.0123, -0.2022, -0.0602,  0.3326, -0.3303],
#         [-0.1459,  0.3022, -0.1596, -0.1916,  0.0815, -0.0546,  0.1753,  0.2236],
#         [-0.2135, -0.3491,  0.0296, -0.0286, -0.2963,  0.3507,  0.2133, -0.1651],
#         [-0.1728, -0.1088,  0.1913,  0.3513, -0.3203,  0.3158, -0.3225, -0.2174],
#         [-0.3200, -0.2337, -0.2881, -0.1768,  0.1892,  0.1550,  0.1089, -0.0050]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2850,  0.3379,  0.3220, -0.3423, -0.2008,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3823, -0.2464, -0.2010, -0.0024, -0.0132,  0.4059],
#         [-0.2486,  0.2933,  0.3579, -0.2035, -0.2270,  0.2971],
#         [ 0.3402, -0.1067, -0.3583,  0.3600,  0.0912,  0.2988],
#         [ 0.0103, -0.1019, -0.0993,  0.2491, -0.2033,  0.3989]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2052,  0.2722, -0.3887,  0.3415], requires_grad=True)
# Parameter containing:
# tensor([[-0.1495, -0.1199,  0.2272,  0.3873]], requires_grad=True)
# Parameter containing:
# tensor([0.3719], requires_grad=True)
# loss=0.8015468716621399
# Parameter containing:
# tensor([[ 0.1499, -0.0680,  0.0974,  0.0280, -0.3170,  0.1075, -0.0027, -0.2987],
#         [ 0.0724, -0.2046,  0.1400, -0.0123, -0.2022, -0.0602,  0.3326, -0.3303],
#         [-0.1459,  0.3022, -0.1596, -0.1916,  0.0815, -0.0546,  0.1753,  0.2236],
#         [-0.2135, -0.3491,  0.0296, -0.0286, -0.2963,  0.3507,  0.2133, -0.1651],
#         [-0.1728, -0.1087,  0.1914,  0.3513, -0.3203,  0.3158, -0.3225, -0.2174],
#         [-0.3200, -0.2337, -0.2881, -0.1768,  0.1891,  0.1550,  0.1089, -0.0050]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2850,  0.3379,  0.3220, -0.3423, -0.2008,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3823, -0.2464, -0.2009, -0.0024, -0.0132,  0.4059],
#         [-0.2486,  0.2933,  0.3579, -0.2035, -0.2270,  0.2971],
#         [ 0.3402, -0.1067, -0.3584,  0.3600,  0.0912,  0.2988],
#         [ 0.0103, -0.1019, -0.0996,  0.2491, -0.2034,  0.3989]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2053,  0.2723, -0.3888,  0.3412], requires_grad=True)
# Parameter containing:
# tensor([[-0.1509, -0.1216,  0.2263,  0.3858]], requires_grad=True)
# Parameter containing:
# tensor([0.3692], requires_grad=True)
# loss=0.799968421459198
# Parameter containing:
# tensor([[ 0.1499, -0.0681,  0.0973,  0.0279, -0.3170,  0.1074, -0.0027, -0.2987],
#         [ 0.0724, -0.2046,  0.1400, -0.0123, -0.2022, -0.0602,  0.3326, -0.3303],
#         [-0.1459,  0.3022, -0.1596, -0.1916,  0.0815, -0.0546,  0.1753,  0.2236],
#         [-0.2135, -0.3491,  0.0296, -0.0286, -0.2963,  0.3507,  0.2133, -0.1651],
#         [-0.1728, -0.1087,  0.1914,  0.3513, -0.3203,  0.3158, -0.3225, -0.2174],
#         [-0.3200, -0.2337, -0.2882, -0.1768,  0.1891,  0.1550,  0.1089, -0.0050]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2850,  0.3379,  0.3220, -0.3423, -0.2008,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3823, -0.2464, -0.2008, -0.0024, -0.0131,  0.4059],
#         [-0.2486,  0.2933,  0.3580, -0.2035, -0.2270,  0.2971],
#         [ 0.3401, -0.1067, -0.3586,  0.3600,  0.0911,  0.2988],
#         [ 0.0103, -0.1019, -0.0999,  0.2491, -0.2035,  0.3989]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2054,  0.2724, -0.3890,  0.3409], requires_grad=True)
# Parameter containing:
# tensor([[-0.1523, -0.1233,  0.2254,  0.3843]], requires_grad=True)
# Parameter containing:
# tensor([0.3664], requires_grad=True)
# loss=0.7984054684638977
# Parameter containing:
# tensor([[ 0.1499, -0.0682,  0.0972,  0.0279, -0.3170,  0.1074, -0.0027, -0.2987],
#         [ 0.0724, -0.2046,  0.1400, -0.0123, -0.2022, -0.0602,  0.3326, -0.3303],
#         [-0.1459,  0.3022, -0.1596, -0.1916,  0.0815, -0.0546,  0.1753,  0.2236],
#         [-0.2135, -0.3491,  0.0296, -0.0286, -0.2963,  0.3507,  0.2133, -0.1651],
#         [-0.1728, -0.1087,  0.1914,  0.3513, -0.3203,  0.3158, -0.3225, -0.2173],
#         [-0.3200, -0.2338, -0.2882, -0.1768,  0.1891,  0.1550,  0.1089, -0.0050]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2850,  0.3379,  0.3220, -0.3423, -0.2008,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3823, -0.2464, -0.2007, -0.0024, -0.0131,  0.4059],
#         [-0.2486,  0.2933,  0.3581, -0.2035, -0.2269,  0.2971],
#         [ 0.3401, -0.1067, -0.3587,  0.3600,  0.0910,  0.2988],
#         [ 0.0103, -0.1019, -0.1001,  0.2491, -0.2037,  0.3989]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2055,  0.2724, -0.3891,  0.3407], requires_grad=True)
# Parameter containing:
# tensor([[-0.1537, -0.1250,  0.2244,  0.3829]], requires_grad=True)
# Parameter containing:
# tensor([0.3637], requires_grad=True)
# loss=0.7968582510948181
# Parameter containing:
# tensor([[ 0.1499, -0.0683,  0.0971,  0.0279, -0.3170,  0.1074, -0.0027, -0.2987],
#         [ 0.0724, -0.2046,  0.1400, -0.0123, -0.2022, -0.0602,  0.3326, -0.3303],
#         [-0.1459,  0.3022, -0.1596, -0.1916,  0.0815, -0.0546,  0.1753,  0.2236],
#         [-0.2135, -0.3491,  0.0296, -0.0286, -0.2963,  0.3507,  0.2133, -0.1651],
#         [-0.1728, -0.1086,  0.1915,  0.3513, -0.3203,  0.3158, -0.3225, -0.2173],
#         [-0.3200, -0.2338, -0.2882, -0.1768,  0.1890,  0.1550,  0.1089, -0.0050]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2850,  0.3379,  0.3220, -0.3423, -0.2008,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3822, -0.2464, -0.2006, -0.0024, -0.0130,  0.4059],
#         [-0.2486,  0.2933,  0.3582, -0.2035, -0.2269,  0.2971],
#         [ 0.3401, -0.1067, -0.3588,  0.3600,  0.0910,  0.2988],
#         [ 0.0103, -0.1019, -0.1004,  0.2491, -0.2038,  0.3989]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2056,  0.2725, -0.3892,  0.3404], requires_grad=True)
# Parameter containing:
# tensor([[-0.1550, -0.1268,  0.2235,  0.3814]], requires_grad=True)
# Parameter containing:
# tensor([0.3610], requires_grad=True)
# loss=0.7953264713287354
# Parameter containing:
# tensor([[ 0.1499, -0.0684,  0.0970,  0.0279, -0.3170,  0.1073, -0.0027, -0.2988],
#         [ 0.0724, -0.2046,  0.1400, -0.0123, -0.2022, -0.0602,  0.3326, -0.3303],
# ...
# Parameter containing:
# tensor([-0.1679], requires_grad=True)
# loss=0.6472676992416382
# Parameter containing:
# tensor([[ 0.1501, -0.0880,  0.0874,  0.0276, -0.3172,  0.1048, -0.0027, -0.2996],
#         [ 0.0724, -0.2046,  0.1415, -0.0116, -0.2021, -0.0595,  0.3326, -0.3298],
#         [-0.1459,  0.3025, -0.1592, -0.1914,  0.0815, -0.0545,  0.1753,  0.2237],
#         [-0.2135, -0.3491,  0.0261, -0.0295, -0.2974,  0.3494,  0.2133, -0.1661],
#         [-0.1718, -0.0858,  0.1981,  0.3484, -0.3266,  0.3200, -0.3224, -0.2119],
#         [-0.3203, -0.2312, -0.2854, -0.1771,  0.1946,  0.1564,  0.1089, -0.0057]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2851,  0.3379,  0.3220, -0.3423, -0.2007,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3819, -0.2460, -0.1624, -0.0025,  0.0167,  0.4028],
#         [-0.2483,  0.2937,  0.3948, -0.2036, -0.1976,  0.2942],
#         [ 0.3400, -0.1068, -0.3747,  0.3600,  0.0814,  0.2990],
#         [ 0.0099, -0.1021, -0.1322,  0.2490, -0.2233,  0.3995]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2439,  0.3093, -0.4051,  0.3084], requires_grad=True)
# Parameter containing:
# tensor([[-0.4207, -0.4550,  0.0505,  0.1131]], requires_grad=True)
# Parameter containing:
# tensor([-0.1680], requires_grad=True)
# loss=0.6472674012184143
# Parameter containing:
# tensor([[ 0.1501, -0.0880,  0.0874,  0.0276, -0.3172,  0.1048, -0.0027, -0.2996],
#         [ 0.0724, -0.2046,  0.1415, -0.0116, -0.2021, -0.0595,  0.3326, -0.3298],
#         [-0.1459,  0.3025, -0.1592, -0.1914,  0.0815, -0.0545,  0.1753,  0.2237],
#         [-0.2135, -0.3491,  0.0261, -0.0295, -0.2974,  0.3494,  0.2133, -0.1661],
#         [-0.1718, -0.0858,  0.1981,  0.3484, -0.3266,  0.3200, -0.3224, -0.2119],
#         [-0.3203, -0.2312, -0.2854, -0.1771,  0.1946,  0.1564,  0.1089, -0.0057]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2851,  0.3379,  0.3220, -0.3423, -0.2007,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3819, -0.2460, -0.1624, -0.0025,  0.0167,  0.4028],
#         [-0.2483,  0.2937,  0.3948, -0.2036, -0.1976,  0.2942],
#         [ 0.3400, -0.1068, -0.3747,  0.3600,  0.0814,  0.2990],
#         [ 0.0099, -0.1021, -0.1322,  0.2490, -0.2233,  0.3995]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2439,  0.3093, -0.4051,  0.3084], requires_grad=True)
# Parameter containing:
# tensor([[-0.4207, -0.4550,  0.0505,  0.1131]], requires_grad=True)
# Parameter containing:
# tensor([-0.1680], requires_grad=True)
# loss=0.6472671627998352
# Parameter containing:
# tensor([[ 0.1501, -0.0880,  0.0874,  0.0276, -0.3172,  0.1048, -0.0027, -0.2996],
#         [ 0.0724, -0.2046,  0.1415, -0.0116, -0.2021, -0.0595,  0.3326, -0.3298],
#         [-0.1459,  0.3025, -0.1592, -0.1914,  0.0815, -0.0545,  0.1753,  0.2237],
#         [-0.2135, -0.3491,  0.0261, -0.0295, -0.2974,  0.3494,  0.2133, -0.1661],
#         [-0.1718, -0.0858,  0.1981,  0.3484, -0.3266,  0.3200, -0.3224, -0.2119],
#         [-0.3203, -0.2312, -0.2854, -0.1771,  0.1946,  0.1564,  0.1089, -0.0057]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2851,  0.3379,  0.3220, -0.3423, -0.2007,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3819, -0.2460, -0.1624, -0.0025,  0.0167,  0.4028],
#         [-0.2483,  0.2937,  0.3948, -0.2036, -0.1976,  0.2942],
#         [ 0.3400, -0.1068, -0.3747,  0.3600,  0.0814,  0.2990],
#         [ 0.0099, -0.1021, -0.1322,  0.2490, -0.2233,  0.3995]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2439,  0.3093, -0.4051,  0.3084], requires_grad=True)
# Parameter containing:
# tensor([[-0.4208, -0.4550,  0.0505,  0.1131]], requires_grad=True)
# Parameter containing:
# tensor([-0.1680], requires_grad=True)
# loss=0.6472669243812561
# Parameter containing:
# tensor([[ 0.1501, -0.0880,  0.0874,  0.0276, -0.3172,  0.1048, -0.0027, -0.2996],
#         [ 0.0724, -0.2046,  0.1415, -0.0116, -0.2021, -0.0595,  0.3326, -0.3298],
#         [-0.1459,  0.3025, -0.1592, -0.1914,  0.0815, -0.0545,  0.1753,  0.2237],
#         [-0.2135, -0.3491,  0.0261, -0.0295, -0.2974,  0.3494,  0.2133, -0.1661],
#         [-0.1718, -0.0857,  0.1981,  0.3484, -0.3266,  0.3200, -0.3224, -0.2119],
#         [-0.3203, -0.2312, -0.2854, -0.1771,  0.1946,  0.1564,  0.1089, -0.0057]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2851,  0.3379,  0.3220, -0.3423, -0.2007,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3819, -0.2460, -0.1624, -0.0025,  0.0167,  0.4028],
#         [-0.2483,  0.2937,  0.3948, -0.2036, -0.1976,  0.2942],
#         [ 0.3400, -0.1068, -0.3747,  0.3600,  0.0814,  0.2990],
#         [ 0.0099, -0.1021, -0.1322,  0.2490, -0.2233,  0.3995]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2439,  0.3093, -0.4051,  0.3084], requires_grad=True)
# Parameter containing:
# tensor([[-0.4208, -0.4550,  0.0505,  0.1131]], requires_grad=True)
# Parameter containing:
# tensor([-0.1681], requires_grad=True)
# loss=0.6472666263580322
# Parameter containing:
# tensor([[ 0.1501, -0.0880,  0.0874,  0.0276, -0.3172,  0.1048, -0.0027, -0.2996],
#         [ 0.0724, -0.2046,  0.1415, -0.0116, -0.2021, -0.0595,  0.3326, -0.3298],
#         [-0.1459,  0.3025, -0.1592, -0.1914,  0.0815, -0.0545,  0.1753,  0.2237],
#         [-0.2135, -0.3491,  0.0261, -0.0295, -0.2974,  0.3494,  0.2133, -0.1661],
#         [-0.1718, -0.0857,  0.1981,  0.3484, -0.3266,  0.3200, -0.3224, -0.2119],
#         [-0.3203, -0.2312, -0.2854, -0.1771,  0.1946,  0.1564,  0.1089, -0.0057]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2851,  0.3379,  0.3220, -0.3423, -0.2007,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3819, -0.2460, -0.1624, -0.0025,  0.0167,  0.4028],
#         [-0.2483,  0.2937,  0.3948, -0.2036, -0.1975,  0.2942],
#         [ 0.3400, -0.1068, -0.3747,  0.3600,  0.0814,  0.2990],
#         [ 0.0099, -0.1021, -0.1322,  0.2490, -0.2233,  0.3995]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2439,  0.3093, -0.4051,  0.3084], requires_grad=True)
# Parameter containing:
# tensor([[-0.4208, -0.4550,  0.0505,  0.1131]], requires_grad=True)
# Parameter containing:
# tensor([-0.1681], requires_grad=True)
# loss=0.6472663283348083
# Parameter containing:
# tensor([[ 0.1501, -0.0880,  0.0874,  0.0276, -0.3172,  0.1048, -0.0027, -0.2996],
#         [ 0.0724, -0.2046,  0.1415, -0.0116, -0.2021, -0.0595,  0.3326, -0.3298],
#         [-0.1459,  0.3025, -0.1592, -0.1914,  0.0815, -0.0545,  0.1753,  0.2237],
#         [-0.2135, -0.3491,  0.0261, -0.0295, -0.2974,  0.3494,  0.2133, -0.1661],
#         [-0.1718, -0.0857,  0.1981,  0.3484, -0.3266,  0.3200, -0.3224, -0.2119],
#         [-0.3203, -0.2312, -0.2854, -0.1771,  0.1946,  0.1564,  0.1089, -0.0057]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2851,  0.3379,  0.3220, -0.3423, -0.2007,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3819, -0.2460, -0.1624, -0.0025,  0.0167,  0.4028],
#         [-0.2483,  0.2937,  0.3948, -0.2036, -0.1975,  0.2942],
#         [ 0.3400, -0.1068, -0.3747,  0.3600,  0.0814,  0.2991],
#         [ 0.0099, -0.1021, -0.1322,  0.2490, -0.2233,  0.3995]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2439,  0.3093, -0.4051,  0.3084], requires_grad=True)
# Parameter containing:
# tensor([[-0.4208, -0.4550,  0.0505,  0.1131]], requires_grad=True)
# Parameter containing:
# tensor([-0.1681], requires_grad=True)
# loss=0.6472662091255188
# Parameter containing:
# tensor([[ 0.1501, -0.0880,  0.0874,  0.0276, -0.3172,  0.1048, -0.0027, -0.2996],
#         [ 0.0724, -0.2046,  0.1415, -0.0116, -0.2021, -0.0595,  0.3326, -0.3298],
#         [-0.1459,  0.3025, -0.1592, -0.1914,  0.0815, -0.0545,  0.1753,  0.2237],
#         [-0.2135, -0.3491,  0.0260, -0.0295, -0.2974,  0.3494,  0.2133, -0.1661],
#         [-0.1718, -0.0857,  0.1981,  0.3484, -0.3266,  0.3200, -0.3224, -0.2119],
#         [-0.3203, -0.2312, -0.2854, -0.1771,  0.1946,  0.1564,  0.1089, -0.0057]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2851,  0.3379,  0.3220, -0.3423, -0.2007,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3819, -0.2460, -0.1624, -0.0025,  0.0168,  0.4028],
#         [-0.2483,  0.2937,  0.3948, -0.2036, -0.1975,  0.2942],
#         [ 0.3400, -0.1068, -0.3747,  0.3600,  0.0814,  0.2991],
#         [ 0.0099, -0.1021, -0.1322,  0.2490, -0.2233,  0.3995]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2439,  0.3093, -0.4051,  0.3084], requires_grad=True)
# Parameter containing:
# tensor([[-0.4208, -0.4551,  0.0505,  0.1131]], requires_grad=True)
# Parameter containing:
# tensor([-0.1681], requires_grad=True)
# loss=0.6472658514976501
# Parameter containing:
# tensor([[ 0.1501, -0.0880,  0.0874,  0.0276, -0.3172,  0.1048, -0.0027, -0.2996],
#         [ 0.0724, -0.2046,  0.1415, -0.0116, -0.2021, -0.0595,  0.3326, -0.3298],
#         [-0.1459,  0.3025, -0.1592, -0.1914,  0.0815, -0.0545,  0.1753,  0.2237],
#         [-0.2135, -0.3491,  0.0260, -0.0295, -0.2974,  0.3494,  0.2133, -0.1661],
#         [-0.1718, -0.0856,  0.1981,  0.3484, -0.3266,  0.3200, -0.3224, -0.2119],
#         [-0.3203, -0.2312, -0.2854, -0.1771,  0.1946,  0.1564,  0.1089, -0.0057]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2851,  0.3379,  0.3220, -0.3423, -0.2007,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3819, -0.2460, -0.1624, -0.0025,  0.0168,  0.4027],
#         [-0.2483,  0.2937,  0.3948, -0.2036, -0.1975,  0.2942],
#         [ 0.3400, -0.1068, -0.3747,  0.3600,  0.0814,  0.2991],
#         [ 0.0099, -0.1021, -0.1322,  0.2490, -0.2233,  0.3995]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2439,  0.3093, -0.4051,  0.3084], requires_grad=True)
# Parameter containing:
# tensor([[-0.4208, -0.4551,  0.0505,  0.1131]], requires_grad=True)
# Parameter containing:
# tensor([-0.1682], requires_grad=True)
# loss=0.6472656726837158
# Parameter containing:
# tensor([[ 0.1501, -0.0880,  0.0874,  0.0276, -0.3172,  0.1048, -0.0027, -0.2996],
#         [ 0.0724, -0.2046,  0.1415, -0.0116, -0.2021, -0.0595,  0.3326, -0.3298],
#         [-0.1459,  0.3025, -0.1592, -0.1914,  0.0815, -0.0545,  0.1753,  0.2237],
#         [-0.2135, -0.3491,  0.0260, -0.0295, -0.2974,  0.3494,  0.2133, -0.1661],
#         [-0.1718, -0.0856,  0.1981,  0.3484, -0.3267,  0.3200, -0.3224, -0.2119],
#         [-0.3203, -0.2312, -0.2854, -0.1771,  0.1946,  0.1565,  0.1089, -0.0057]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2851,  0.3379,  0.3220, -0.3423, -0.2007,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3819, -0.2460, -0.1624, -0.0025,  0.0168,  0.4027],
#         [-0.2483,  0.2937,  0.3949, -0.2036, -0.1975,  0.2942],
#         [ 0.3400, -0.1068, -0.3747,  0.3600,  0.0814,  0.2991],
#         [ 0.0099, -0.1021, -0.1322,  0.2490, -0.2233,  0.3995]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2439,  0.3093, -0.4051,  0.3084], requires_grad=True)
# Parameter containing:
# tensor([[-0.4208, -0.4551,  0.0504,  0.1131]], requires_grad=True)
# Parameter containing:
# tensor([-0.1682], requires_grad=True)
# loss=0.6472653746604919
# Parameter containing:
# tensor([[ 0.1501, -0.0881,  0.0874,  0.0276, -0.3172,  0.1048, -0.0027, -0.2996],
#         [ 0.0724, -0.2046,  0.1415, -0.0116, -0.2021, -0.0595,  0.3326, -0.3298],
#         [-0.1459,  0.3025, -0.1592, -0.1914,  0.0815, -0.0545,  0.1753,  0.2237],
#         [-0.2135, -0.3491,  0.0260, -0.0295, -0.2974,  0.3493,  0.2133, -0.1661],
#         [-0.1718, -0.0856,  0.1981,  0.3484, -0.3267,  0.3200, -0.3224, -0.2119],
#         [-0.3203, -0.2312, -0.2854, -0.1771,  0.1946,  0.1565,  0.1089, -0.0057]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2851,  0.3379,  0.3220, -0.3423, -0.2007,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3819, -0.2460, -0.1624, -0.0025,  0.0168,  0.4027],
#         [-0.2483,  0.2937,  0.3949, -0.2036, -0.1975,  0.2942],
#         [ 0.3400, -0.1068, -0.3747,  0.3600,  0.0814,  0.2991],
#         [ 0.0099, -0.1021, -0.1322,  0.2490, -0.2233,  0.3995]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2439,  0.3093, -0.4051,  0.3084], requires_grad=True)
# Parameter containing:
# tensor([[-0.4208, -0.4551,  0.0504,  0.1131]], requires_grad=True)
# Parameter containing:
# tensor([-0.1682], requires_grad=True)
# loss=0.6472651362419128
# Parameter containing:
# tensor([[ 0.1501, -0.0881,  0.0874,  0.0276, -0.3172,  0.1048, -0.0027, -0.2996],
#         [ 0.0724, -0.2046,  0.1415, -0.0116, -0.2021, -0.0595,  0.3326, -0.3298],
#         [-0.1459,  0.3025, -0.1592, -0.1914,  0.0815, -0.0545,  0.1753,  0.2237],
#         [-0.2135, -0.3491,  0.0260, -0.0295, -0.2974,  0.3493,  0.2133, -0.1661],
#         [-0.1718, -0.0856,  0.1981,  0.3484, -0.3267,  0.3200, -0.3224, -0.2119],
#         [-0.3203, -0.2312, -0.2854, -0.1771,  0.1946,  0.1565,  0.1089, -0.0057]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2851,  0.3379,  0.3220, -0.3423, -0.2007,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3819, -0.2460, -0.1624, -0.0025,  0.0168,  0.4027],
#         [-0.2483,  0.2937,  0.3949, -0.2036, -0.1975,  0.2942],
#         [ 0.3400, -0.1068, -0.3747,  0.3600,  0.0814,  0.2991],
#         [ 0.0099, -0.1021, -0.1322,  0.2490, -0.2233,  0.3995]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2439,  0.3093, -0.4051,  0.3084], requires_grad=True)
# Parameter containing:
# tensor([[-0.4208, -0.4551,  0.0504,  0.1131]], requires_grad=True)
# Parameter containing:
# tensor([-0.1683], requires_grad=True)
# loss=0.647264838218689
# Parameter containing:
# tensor([[ 0.1501, -0.0881,  0.0874,  0.0276, -0.3172,  0.1048, -0.0027, -0.2996],
#         [ 0.0724, -0.2046,  0.1415, -0.0116, -0.2021, -0.0595,  0.3326, -0.3298],
#         [-0.1459,  0.3025, -0.1592, -0.1914,  0.0815, -0.0545,  0.1753,  0.2237],
#         [-0.2135, -0.3491,  0.0260, -0.0295, -0.2974,  0.3493,  0.2133, -0.1661],
#         [-0.1718, -0.0855,  0.1981,  0.3484, -0.3267,  0.3200, -0.3224, -0.2119],
#         [-0.3203, -0.2312, -0.2854, -0.1771,  0.1946,  0.1565,  0.1089, -0.0057]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2851,  0.3379,  0.3220, -0.3423, -0.2007,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3819, -0.2460, -0.1624, -0.0025,  0.0168,  0.4027],
#         [-0.2483,  0.2937,  0.3949, -0.2036, -0.1974,  0.2942],
#         [ 0.3400, -0.1068, -0.3747,  0.3600,  0.0814,  0.2991],
#         [ 0.0099, -0.1021, -0.1322,  0.2490, -0.2233,  0.3995]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2439,  0.3093, -0.4051,  0.3084], requires_grad=True)
# Parameter containing:
# tensor([[-0.4208, -0.4551,  0.0504,  0.1131]], requires_grad=True)
# Parameter containing:
# tensor([-0.1683], requires_grad=True)
# loss=0.6472645401954651
# Parameter containing:
# tensor([[ 0.1501, -0.0881,  0.0874,  0.0276, -0.3172,  0.1049, -0.0027, -0.2996],
#         [ 0.0724, -0.2046,  0.1415, -0.0116, -0.2021, -0.0595,  0.3326, -0.3298],
#         [-0.1459,  0.3025, -0.1592, -0.1914,  0.0815, -0.0545,  0.1753,  0.2237],
#         [-0.2135, -0.3491,  0.0260, -0.0295, -0.2974,  0.3493,  0.2133, -0.1661],
#         [-0.1718, -0.0855,  0.1981,  0.3484, -0.3267,  0.3200, -0.3224, -0.2119],
#         [-0.3203, -0.2312, -0.2854, -0.1771,  0.1946,  0.1565,  0.1089, -0.0058]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.2851,  0.3379,  0.3220, -0.3423, -0.2007,  0.2353],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.3819, -0.2460, -0.1624, -0.0025,  0.0168,  0.4027],
#         [-0.2483,  0.2937,  0.3949, -0.2036, -0.1974,  0.2942],
#         [ 0.3400, -0.1068, -0.3747,  0.3600,  0.0814,  0.2991],
#         [ 0.0099, -0.1021, -0.1322,  0.2490, -0.2233,  0.3995]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.2439,  0.3093, -0.4051,  0.3084], requires_grad=True)
# Parameter containing:
# tensor([[-0.4209, -0.4551,  0.0504,  0.1131]], requires_grad=True)
# Parameter containing:
# tensor([-0.1683], requires_grad=True)
# loss=0.6472643613815308

# %%
train_cnt = np.linspace(1, epoch, epoch)
print(loss_history)
# Out:
# [0.8656423091888428, 0.8634384274482727, 0.8612554669380188, 0.8590934872627258, 0.856952428817749, 0.8548317551612854, 0.8527315258979797, 0.8506516814231873, 0.8485917448997498, 0.8465516567230225, 0.8445315361022949, 0.8425307273864746, 0.8405494689941406, 0.8385874629020691, 0.8366444706916809, 0.8347203731536865, 0.8328151702880859, 0.8309283256530762, 0.8290600776672363, 0.8272101283073425, 0.8253781199455261, 0.8235641121864319, 0.821768045425415, 0.8199895024299622, 0.8182284235954285, 0.8164848685264587, 0.8147582411766052, 0.813048779964447, 0.8113560676574707, 0.8096804022789001, 0.808021068572998, 0.806378185749054, 0.8047516942024231, 0.8031412959098816, 0.8015468716621399, 0.799968421459198, 0.7984054684638977, 0.7968582510948181, 0.7953264713287354, 0.7938098907470703, 0.7923085689544678, 0.7908222079277039, 0.7893507480621338, 0.7878939509391785, 0.7864518165588379, 0.7850241661071777, 0.7836108207702637, 0.7822117209434509, 0.7808266282081604, 0.7794556021690369, 0.7780982851982117, 0.77675461769104, 0.7754246592521667, 0.7741079926490784, 0.7728047370910645, 0.7715145945549011, 0.7702374458312988, 0.7689733505249023, 0.7677220702171326, 0.7664834856987, 0.7652572989463806, 0.7640436291694641, 0.7628424167633057, 0.7616533637046814, 0.7604763507843018, 0.7593113780021667, 0.7581582069396973, 0.7570168375968933, 0.7558870911598206, 0.7547688484191895, 0.753662109375, 0.7525666356086731, 0.7514823079109192, 0.7504090666770935, 0.7493467926979065, 0.7482954859733582, 0.7472549080848694, 0.7462248802185059, 0.7452055811882019, 0.7441967129707336, 0.7431980967521667, 0.7422098517417908, 0.7412316799163818, 0.7402635216712952, 0.739305317401886, 0.7383570671081543, 0.7374184727668762, 0.7364895939826965, 0.7355702519416809, 0.7346603870391846, 0.7337598204612732, 0.7328686714172363, 0.7319867014884949, 0.7311136722564697, 0.73024982213974, 0.7293947339057922, 0.728548526763916, 0.7277111411094666, 0.7268823981285095, 0.7260621190071106, 0.7252504229545593, 0.7244470715522766, 0.7236519455909729, 0.722865104675293, 0.7220864295959473, 0.721315860748291, 0.7205531597137451, 0.7197983860969543, 0.7190515398979187, 0.7183122634887695, 0.7175807356834412, 0.7168567776679993, 0.7161404490470886, 0.7154313921928406, 0.7147296071052551, 0.7140353322029114, 0.7133481502532959, 0.7126680016517639, 0.7119951248168945, 0.7113289833068848, 0.710669994354248, 0.710017740726471, 0.7093722820281982, 0.7087334990501404, 0.7081012725830078, 0.7074756622314453, 0.7068565487861633, 0.7062439918518066, 0.7056376934051514, 0.7050377726554871, 0.7044439315795898, 0.7038564085960388, 0.7032749652862549, 0.7026996612548828, 0.7021302580833435, 0.7015666961669922, 0.7010089755058289, 0.7004571557044983, 0.6999110579490662, 0.6993706822395325, 0.6988358497619629, 0.6983066201210022, 0.6977828145027161, 0.6972644925117493, 0.6967517733573914, 0.6962441802024841, 0.6957419514656067, 0.6952447891235352, 0.6947529911994934, 0.6942662596702576, 0.6937845349311829, 0.6933078765869141, 0.6928362250328064, 0.6923694014549255, 0.6919074058532715, 0.6914501786231995, 0.690997838973999, 0.6905501484870911, 0.6901071667671204, 0.6896687150001526, 0.6892349123954773, 0.6888055801391602, 0.688380777835846, 0.6879603266716003, 0.6875442862510681, 0.6871324181556702, 0.6867249608039856, 0.6863217949867249, 0.6859228014945984, 0.6855278611183167, 0.6851372122764587, 0.684750497341156, 0.684367835521698, 0.6839890480041504, 0.6836142539978027, 0.6832435131072998, 0.6828764081001282, 0.6825132369995117, 0.6821537613868713, 0.6817981600761414, 0.6814461350440979, 0.6810978055000305, 0.680753231048584, 0.6804120540618896, 0.6800743937492371, 0.6797404289245605, 0.6794097423553467, 0.6790826916694641, 0.6787588596343994, 0.6784384846687317, 0.6781213879585266, 0.6778075695037842, 0.6774970889091492, 0.6771897673606873, 0.6768856644630432, 0.6765847206115723, 0.6762868762016296, 0.6759921908378601, 0.6757004261016846, 0.6754117608070374, 0.6751260757446289, 0.67484 ...

# %%
plt.plot(train_cnt, loss_history)
plt.xlabel("train_cnt")
plt.ylabel("loss")
# Out:
# Text(0, 0.5, 'loss')
